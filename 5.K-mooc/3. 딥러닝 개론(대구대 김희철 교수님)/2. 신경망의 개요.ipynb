# %%
#신경망 모델링 개요
#신경망 동작 사례
#뉴런의 연산모델

# %%
#뉴런은 정보처리의 단위 이고 신호를 다른 뉴런에 전달해서
#전달한 신호를 다른 뉴런에 출력하는 개념

# %%
#신호를 받는 부분을 Dentrite라고 하고, 신호를 전달하는 통로를 축삭이라고 한다

# %%
#두 뉴런이 서로 동시에 발화하는 상황이 발생하면, 시냅스의 강도가 강해진다

# %%
#동시에 발화가 된다는것은, 시냅스가 서로 열려있어서 자극을 주면 자극을 받는 뉴런이 바로 활성화가 된다는 개념

# %%
#기타 유래에 관한 내용 생략

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('1.jpg')
plt.imshow(image)

# %%
image = Image.open('2.jpg')
plt.imshow(image)

# %%
#가중치에 따라 다른 값이 나오므로, 학습의 목적을 제대로 설정해야함

# %%
image = Image.open('3.jpg')
plt.imshow(image)

# %%
#같은 가중치에 input값이 다를경우도 고려

# %%
image = Image.open('4.jpg')
plt.imshow(image)

# %%
#input이 weight를 지나며 bias를 더하고, activation function를 통해 output이 나오는 구조

# %%
image = Image.open('5.jpg')
plt.imshow(image)

# %%
#그래서 뉴런은 p-차원의 실수벡터 x1,x2,..,xn 을 받았을때,
#벡터를 1-차원 함수로 매핑하는 함수

# %%
##활성화 함수의 종류 ##

# %%
#activation function(활성화 함수)는 뉴런의 동작을 결정한다.

# %%
# 1. 선형 함수
image = Image.open('6.jpg')
plt.imshow(image)

# %%
#입력가중합을 그대로 출력으로 내보낸다. 아무역할을 하지않음. 그래서 단순 선형함수

# %%
#2. piecewise-linear function
image = Image.open('7.jpg')
plt.imshow(image)

# %%
# x가 -1부터 1까지는 단순선형함수와 같지만,
# x가 -1 이하거나, 1이상인 경우 값이 변하지않음

# %%
# 특정한 구간을 넘어서면 출력을 변화시키지않고 그대로 유지

# %%
# Rectified Linear Function ( Relu)
image = Image.open('8.jpg')
plt.imshow(image)

# %%
#0보다 클때는 선형함수의 값을 갖지만, 0보다 작은 구간에서는 무조건 0으로 유지
# 가중합이 음수일 경우에는 출력이 무조건 0이며, 가중합이 양수일 경우 상한값이 따로 없이 계속 선형으로 증가

# %%
#sigmoid 함수를 사용할경우, 기울기소실이나 포화상태의 문제점이 발생해서 학습이 잘 안되는 단점이 있었는데
#이를 relu를 통해 해결함

# %%
#Leaky ReLU
#음수부분에서 0값을 유지하는 대신 기울기가 약간 완만한 선형
#그림의 빨간선

# %%
#Binary Threshold Function(BTU)
image = Image.open('9.jpg')
plt.imshow(image)

# %%
#일정부분까지는 0, 그 이상부터는 무조건 1
# 퍼셉트론이라는 초기뉴럴네트워크에서 위의 activation 함수를 채택

# %%
#비선형 활성화 함수

# %%
#sigmoid
image = Image.open('10.jpg')
plt.imshow(image)

# %%
#입력의 전체범위에서 출력의범위는 0부터 시작해서 천천히증가하다가
#x = 0일때, y = 0.5가 되며
#x가 커질수록 1에 가까워지는 형태

# %%
#hyperbolic tangent function
image = Image.open('11.jpg')
plt.imshow(image)

# %%
#시그모이드와 비슷한데 구간의 변경이있음.
#y의 최소,최대값이 -1 to 1임

# %%
##신경망 구조##

# %%
image = Image.open('11.jpg')
plt.imshow(image)

# %%
#feedforward는 입력->출력방향으로 계속 신호전달
#feedback구조는 이전계층으로 다시 신호를 전달
#backpropagtion(억전파)와 관련

# %%
image = Image.open('12.jpg')
plt.imshow(image)

# %%
image = Image.open('13.jpg')
plt.imshow(image)

# %%
#그림에서 아래의 구조가 feedback 연결선 구조
