# %%
#오류정정 학습법
#viener-hopf (빈-호프)방정식

# %%
#steepest descent기법과 델타법

# %%
#viener필터
#신호잡음을 최소화 하기위한 선형필터 모델

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('14.jpg')
plt.imshow(image)

# %%
#신호에 가중치가 곱해져서 각각의 합이 실제출력을 이룬다

# %%
#viener필터모델의 목적은 목표하는 출력과 실제출력이 가장 유사하게 되는 가중치값을 구하는 것

# %%
#loss function을 최소화하는 가중치 W를 산출

# %%
#viener모델은 평균제곱에러 MSE를 사용.

# %%
#값들의 평균을 구한후, (각 값 - 평균)을 제곱한후, 값의 갯수로 나눠줌

# %%
image = Image.open('15.jpg')
plt.imshow(image)

# %%
#wk를 축으로해서 보면 2차함수가 되고, 최솟값이 1개 존재

# %%
#viener-hopf 방정식의 해를 구한다는것은 w1부터 wp까지 모든 w 성분에 대해서 다 해를 구해야함

# %%
image = Image.open('16.jpg')
plt.imshow(image)

# %%
#Ax=b 에서 x를 구하기 위해 양변에 A의 역행렬을 곱해줌

# %%
#가중치행렬 (하늘색)은 위의 결과가 나오게됨

# %%
image = Image.open('17.jpg')
plt.imshow(image)

# %%
#inverse행렬이 없거나, 구하기 쉽지않은 경우
#손실함수의 기울기에 관해 접근함

# %%
#가중치 w1와 w2가 있는데, 위 종형그래프는 global minimum, 전역적으로 최소점이 1개 존재함

# %%
#벡터의 각 성분별로 미분을 하면 error surface의 형태

# %%
image = Image.open('18.jpg')
plt.imshow(image)

# %%
#기울기가 0보다 작으면 오른쪽, 기울기가 0보다 크면 왼쪽
#기울기 부호의 반대방향으로 가면 최소값으로 향해갈수있음

# %%
#경사하강법의 원리

# %%
image = Image.open('19.jpg')
plt.imshow(image)

# %%
#선형 뉴런과 비선형 뉴런에 적용했을때 존재하는 차이점이 있다

# %%
image = Image.open('20.jpg')
plt.imshow(image)

# %%
# 국소 최소값, global이 아닌 local minumum으로 수렴할수도 있다는 것

# %%
image = Image.open('21.jpg')
plt.imshow(image)

# %%
#steepest는 기울기가 가장 큰 쪽을 따라서 계속 이동하는 방법

# %%
#delta rule은 data별로 기울기를 구해서 이동을 하는것

# %%
image = Image.open('22.jpg')
plt.imshow(image)

# %%
image = Image.open('23.jpg')
plt.imshow(image)

# %%
image = Image.open('24.jpg')
plt.imshow(image)
