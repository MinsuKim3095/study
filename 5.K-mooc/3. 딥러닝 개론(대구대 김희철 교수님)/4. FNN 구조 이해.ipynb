# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
#feedforward neural network에 대한 이해

# %%
image = Image.open('./images/41.jpg')
plt.imshow(image)

# %%
image = Image.open('./images/42.jpg')
plt.imshow(image)
