# %%
# 퍼셉트론은 상당히 오래된 Neural Network
# 지금은 크게 사용하지 않는다

# %%
# 하지만 배우는 이유는 Neural Network의 가장 핵심적인 원형을 제공하기 때문

# %%
#퍼셉트론의 구조와 선형분리성, 퍼셉트론의 한계에 대해 배워본다

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('./images/25.jpg')
plt.imshow(image)

# %%
#입력층과 출력층 2개로 구성되어 있으며, 일반적으로 출력층의 뉴런 1개로 퍼셉트론의 모든 성격과 특성을 설명할 수있음

# %%
#뉴런은 매컬러-피츠 모델을 사용하는데, 활성화함수로 시그넘함수를 사용한다

# %%
image = Image.open('./images/26.jpg')
plt.imshow(image)

# %%
# w * x의 합에 임계치 세타를 빼준 값을 사용한다

# %%
# 시그넘함수는 0보다 크면 1 0보다 작으면 -1값을 내보낸다

# %%
#그래서 2가지 Binary를 분류하기 위해 사용한다.

# %%
image = Image.open('./images/27.jpg')
plt.imshow(image)

# %%
#x0을 -1, w0 = 세타라고 가정했을때 출력은 -세타가 나온다.

# %%
#v값은 0부터 p까지 wi*xi로 표현할수있다

# %%
#이를 통해 세타도 가중치와 마찬가지로 학습의 대상이라는 의미

# %%
image = Image.open('./images/28.jpg')
plt.imshow(image)

# %%
# x와 w를 그림과 같은 성분이라고 가정했을때,y(출력값)은 가중치 벡터 * 입력 벡터라고 한다

# %%
image = Image.open('./images/29.jpg')
plt.imshow(image)

# %%
# 퍼셉트론은 v가 0보다 크면 1, 0보다 작으면 -1을 출력하여 이진분류를 할 수 있다

# %%
# 만약 input 성분이 x1 1개뿐이라면 왼쪽과 같은 직선으로 표현할 수 있다
# x1,x2 2개일 경우 평면으로 나타낼수있으며 3개인 경우부터는 입체로 만들수 있다

# %%
image = Image.open('./images/30.jpg')
plt.imshow(image)

# %%
# 선형함수이기때문에, 선형분리가능한 데이터만 분류할 수 있다

# %%
image = Image.open('./images/31.jpg')
plt.imshow(image)

# %%
# OR연산에서는 (0,0)일때만 False, 나머지는 True값으로 판단한다

# %%
# XOR를 구현알수있는 퍼셉트론은 존재하지않는다

# %%
image = Image.open('./images/31.jpg')
plt.imshow(image)

# %%
#선형분리가 되지않기때문

# %%
#이런 한계를 극복하기 위해 계층수를 늘림

# %%
image = Image.open('./images/33.jpg')
plt.imshow(image)

# %%
image = Image.open('./images/34.jpg')
plt.imshow(image)

# %%
#계층수 증가를 통해 은닉 계층이 생기면 x1,x2의 선형결합이 2개가 생기는데, 이를 통해 출력계층의 출력값을 계산한다
