# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
#선형 분리성을 실현하는데 사용되는 학습알고리즘에 대해서 알아본다

# %%
# 퍼센트론 학습 문제
# 분석 기반 학습
# 퍼셉트론 학습 알고리즘

# %%
image = Image.open('./images/35.jpg')
plt.imshow(image)

# %%
#input x와 label d 로 구성
# x가 퍼셉트론을 지나며 산출되는 y값을 d와 비교하며 에러를 수정한다

# %%
# 일반적으로 학습 알고리즘이 없으면 손으로 수식을 만들면서 해를 구할 수 밖에 없다.
image = Image.open('./images/36.jpg')
plt.imshow(image)

# %%
image = Image.open('./images/37.jpg')
plt.imshow(image)

# %%
image = Image.open('./images/38.jpg')
plt.imshow(image)

# %%
# 전 강의와 마찬가지로 XOR연산에서는 은닉층이 없다면 해가 없다

# %%
image = Image.open('./images/39.jpg')
plt.imshow(image)

# %%
image = Image.open('./images/40.jpg')
plt.imshow(image)

# %%
#현재 시각에 가중치에 나중에 생기는 가중치 증분값을 더해서 가중치를 변경한다

# %%
#d-y는 실제학습값과 label의 차이다,

# %%
#목표값에서 출력값을 뺀다음, xi를 곱한후 학습률을 곱해서 기존 가중치에 더한다
